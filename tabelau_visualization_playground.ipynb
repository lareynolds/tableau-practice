# %% [markdown]
# <a href="https://colab.research.google.com/github/lareynolds/tableau-practice/blob/main/tabelau_visualization_playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.options.mode.chained_assignment = None
import random
import numpy as np

# %%
df = pd.DataFrame(columns=('Category', 'Subcategory', 'Datapoint', 'Category - Subcategory - Datapoint'))

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [Category, Subcategory, Datapoint, Category - Subcategory - Datapoint]
# Index: []

# %%
cat_options = ['Healthy', 'Unhealthy']
sub_options = ['Fruit', 'Grain', 'Meat', 'Plant-based Protein', 'Dairy', 'Fats', 'Vegetable', 'Sweets']
health_options = ['Fruit', 'Grain', 'Vegetable', 'Meat', 'Plant-based Protein', 'Dairy']
unhealth_options = ['Fats', 'Sweets']

# %%
random_text = [random.choice(cat_options) for _ in range(60000)]

# %%
df ['Category']= random_text
df.head()
# Out:
#     Category Subcategory Datapoint Category - Subcategory - Datapoint
# 0    Healthy         NaN       NaN                                NaN
# 1  Unhealthy         NaN       NaN                                NaN
# 2  Unhealthy         NaN       NaN                                NaN
# 3  Unhealthy         NaN       NaN                                NaN
# 4  Unhealthy         NaN       NaN                                NaN

# %%
# prompt: if the Category column contains healthy randomly assign a values from the healthy options

for index, row in df.iterrows():
  if row['Category'] == 'Healthy':
    df.loc[index, 'Subcategory'] = random.choice(health_options)

for index, row in df.iterrows():
  if row['Category'] == 'Unhealthy':
    df.loc[index, 'Subcategory'] = random.choice(unhealth_options)

# %%
df.head()
# Out:
#     Category Subcategory Datapoint Category - Subcategory - Datapoint
# 0    Healthy       Fruit       NaN                                NaN
# 1  Unhealthy      Sweets       NaN                                NaN
# 2  Unhealthy        Fats       NaN                                NaN
# 3  Unhealthy      Sweets       NaN                                NaN
# 4  Unhealthy        Fats       NaN                                NaN

# %%
df.shape
# Out:
# (60000, 4)

# %%
fruits = ['Apple', 'Pear', 'Cherry', 'Grapes', 'Orange', 'Banana', 'Peach', 'Plum', 'Strawberries', 'Pineapples', 'Mango', 'Nectarines', 'Melon', 'Papaya', 'Guava', 'Apricots']
grains = ['Wheat', 'Barley', 'Rye', 'Oats', 'Rice', 'Corn', 'Quinoa']
meat = ['Beef', 'Pork', 'Lamb', 'Chicken', 'Turkey', 'Fish', 'Eggs', 'Duck', 'Goose', 'Venison', 'Quail', 'Rabbit']
plant_based_protein = ['Tofu', 'Tempeh', 'Seitan', 'Tempeh', 'Lentils', 'Chickpeas', 'Beans', 'Nuts and Seeds']
dairy = ['Milk', 'Cheese', 'Yogurt', 'Cream']
fats = ['Olive Oil', 'Avacado Oil', 'Grape Seed Oil', 'Butter']
vegetable = ['Corn', 'Potato', 'Tomato', 'Onion', 'Cucumber', 'Lettuce', 'Spinach', 'Broccoli', 'Carrots', 'Cabbage', 'Bell Peppers', 'Zucchini', 'Egg Plant', 'Cauliflower', 'Asparagus', 'Mushrooms', 'Artichokes', 'Peas', 'Squash', 'Beets']
sweets = ['Candy', 'Chocolate', 'Cake', 'Pie', 'Ice Cream', 'Pudding', 'Donuts', 'Cookies']

# %%
total_items = len(fruits) + len(grains) + len(meat) + len(plant_based_protein) + len(dairy) + len(fats) + len(vegetable) + len(sweets)
total_items
# Out:
# 79

# %%
for index, row in df.iterrows():
  if row['Subcategory'] == 'Fruit':
    df.loc[index, 'Datapoint'] = random.choice(fruits)

for index, row in df.iterrows():
  if row['Subcategory'] == 'Grain':
    df.loc[index, 'Datapoint'] = random.choice(grains)

for index, row in df.iterrows():
  if row['Subcategory'] == 'Meat':
    df.loc[index, 'Datapoint'] = random.choice(meat)

for index, row in df.iterrows():
  if row['Subcategory'] == 'Plant-based Protein':
    df.loc[index, 'Datapoint'] = random.choice(plant_based_protein)

for index, row in df.iterrows():
  if row['Subcategory'] == 'Dairy':
    df.loc[index, 'Datapoint'] = random.choice(dairy)

for index, row in df.iterrows():
  if row['Subcategory'] == 'Fats':
    df.loc[index, 'Datapoint'] = random.choice(fats)

for index, row in df.iterrows():
  if row['Subcategory'] == 'Vegetable':
    df.loc[index, 'Datapoint'] = random.choice(vegetable)

for index, row in df.iterrows():
  if row['Subcategory'] == 'Sweets':
    df.loc[index, 'Datapoint'] = random.choice(sweets)

# %%
df.head()
# Out:
#     Category Subcategory    Datapoint Category - Subcategory - Datapoint
# 0    Healthy       Fruit   Nectarines                                NaN
# 1  Unhealthy      Sweets    Ice Cream                                NaN
# 2  Unhealthy        Fats    Olive Oil                                NaN
# 3  Unhealthy      Sweets    Ice Cream                                NaN
# 4  Unhealthy        Fats  Avacado Oil                                NaN

# %%
df.shape
# Out:
# (60000, 4)

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %%
df.shape
# Out:
# (78, 4)

# %%
len(df)
# Out:
# 78

# %%
df.head()
# Out:
#     Category Subcategory    Datapoint Category - Subcategory - Datapoint
# 0    Healthy       Fruit   Nectarines                                NaN
# 1  Unhealthy      Sweets    Ice Cream                                NaN
# 2  Unhealthy        Fats    Olive Oil                                NaN
# 3  Unhealthy        Fats  Avacado Oil                                NaN
# 4  Unhealthy      Sweets      Pudding                                NaN

# %%
def generate_random_positive_numbers(target_sum, num_numbers):
    # Generate random numbers between 1 and the target sum - num_numbers + 1
    # This ensures that the sum of the numbers is at least target_sum
    random_numbers = np.random.randint(1, target_sum - num_numbers + 2, size=num_numbers)

    # Calculate the scaling factor to ensure they add up to the target sum
    scaling_factor = target_sum / random_numbers.sum()

    # Scale the random numbers
    scaled_numbers = (random_numbers * scaling_factor).astype(int)

    # Adjust one of the numbers to make the sum exactly equal to the target
    scaled_numbers[-1] += target_sum - scaled_numbers.sum()

    return scaled_numbers

def fill_row(row):
    random_integers = generate_random_positive_numbers(500, 6)

    # Cast the random integers to integers and fill the cells
    row[['Zero', 'One', 'Two', 'Three', 'Four', 'Five']] = random_integers.astype(int)
    return row

# Create an example DataFrame
df2 = pd.DataFrame(columns=['Zero', 'One', 'Two', 'Three', 'Four', 'Five'])

# Fill the DataFrame with rows that sum to exactly 500
for _ in range(len(df)):
    row = pd.Series([0, 0, 0, 0, 0, 0], index=['Zero', 'One', 'Two', 'Three', 'Four', 'Five'])
    row = pd.DataFrame(fill_row(row))
    row = row.transpose()
    df2 = pd.concat([df2, row], ignore_index=True)

# %%
data = df.merge(df2, left_index=True, right_index=True)

# %%
data['Category - Subcategory - Datapoint'] = (data['Category']) + ' - ' + (data['Subcategory']) + ' - ' + (data['Datapoint'])

# %%
data.head()
# Out:
#     Category Subcategory    Datapoint Category - Subcategory - Datapoint Zero  \
# 0    Healthy       Fruit   Nectarines       Healthy - Fruit - Nectarines   56
# 1  Unhealthy      Sweets    Ice Cream     Unhealthy - Sweets - Ice Cream   91
# 2  Unhealthy        Fats    Olive Oil       Unhealthy - Fats - Olive Oil    5
# 3  Unhealthy        Fats  Avacado Oil     Unhealthy - Fats - Avacado Oil   86
# 4  Unhealthy      Sweets      Pudding       Unhealthy - Sweets - Pudding   97
#
#    One  Two Three Four Five
# 0  109   59    52  165   59
# 1  173  129    69   12   26
# 2  112   21   103  141  118
# 3   25   75   174   20  120
# 4   97   95    89   60   62

# %%
data.to_excel('data.xlsx', index=False)
