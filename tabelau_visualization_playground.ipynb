# %% [markdown]
# <a href="https://colab.research.google.com/github/lareynolds/tableau-practice/blob/main/tabelau_visualization_playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.options.mode.chained_assignment = None
import random
import numpy as np

# %%
df = pd.DataFrame(columns=('Category', 'Subcategory', 'Datapoint', 'Zero','One', 'Two', "Three", 'Four', 'Five'))

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [Category, Subcategory, Datapoint, Zero, One, Two, Three, Four, Five]
# Index: []

# %%
cat_options = ['Healthy', 'Unhealthy', 'Both']
sub_options = ['Fruit', 'Grain', 'Meat', 'Dairy', 'Fats', 'Vegetable', 'Sweets']
health_options = ['Fruit', 'Grain', 'Vegetable']
unhealth_options = ['Fats', 'Sweets']
both_options = ['Meat', 'Dairy']

# %%
random_text = [random.choice(cat_options) for _ in range(500)]

# %%
df ['Category']= random_text
df.head()
# Out:
#     Category Subcategory Datapoint Zero  One  Two Three Four Five
# 0       Both         NaN       NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 1  Unhealthy         NaN       NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 2  Unhealthy         NaN       NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 3  Unhealthy         NaN       NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 4    Healthy         NaN       NaN  NaN  NaN  NaN   NaN  NaN  NaN

# %%
# prompt: if the Category column contains healthy randomly assign a values from the healthy options

for index, row in df.iterrows():
  if row['Category'] == 'Healthy':
    df.loc[index, 'Subcategory'] = random.choice(health_options)

for index, row in df.iterrows():
  if row['Category'] == 'Unhealthy':
    df.loc[index, 'Subcategory'] = random.choice(unhealth_options)

for index, row in df.iterrows():
  if row['Category'] == 'Both':
    df.loc[index, 'Subcategory'] = random.choice(both_options)

# %%
df.head()
# Out:
#     Category Subcategory Datapoint Zero  One  Two Three Four Five
# 0       Both       Dairy       NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 1  Unhealthy        Fats       NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 2  Unhealthy        Fats       NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 3  Unhealthy        Fats       NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 4    Healthy       Grain       NaN  NaN  NaN  NaN   NaN  NaN  NaN

# %%
df.shape
# Out:
# (500, 9)

# %%
fruits = ['Apple', 'Pear', 'Cherry', 'Grapes', 'Orange', 'Banana']
grains = ['Wheat', 'Barley', 'Rye', 'Oats', 'Rice', 'Corn']
meat = ['Beef', 'Pork', 'Lamb', 'Chicken', 'Turkey', 'Fish']
dairy = ['Milk', 'Cheese', 'Yogurt', 'Cream']
fats = ['Olive Oil', 'Avacado Oil', 'Grape Seed Oil', 'Butter']
vegetable = ['Corn', 'Potato', 'Tomato', 'Onion', 'Cucumber', 'Lettuce', 'Spinach', 'Broccoli', 'Carrots', 'Cabbage']
sweets = ['Candy', 'Chocolate', 'Cake', 'Pie', 'Ice Cream', 'Pudding']

# %%
for index, row in df.iterrows():
  if row['Subcategory'] == 'Fruit':
    df.loc[index, 'Datapoint'] = random.choice(fruits)

for index, row in df.iterrows():
  if row['Subcategory'] == 'Grain':
    df.loc[index, 'Datapoint'] = random.choice(grains)

for index, row in df.iterrows():
  if row['Subcategory'] == 'Meat':
    df.loc[index, 'Datapoint'] = random.choice(meat)

for index, row in df.iterrows():
  if row['Subcategory'] == 'Dairy':
    df.loc[index, 'Datapoint'] = random.choice(dairy)

for index, row in df.iterrows():
  if row['Subcategory'] == 'Fats':
    df.loc[index, 'Datapoint'] = random.choice(fats)

for index, row in df.iterrows():
  if row['Subcategory'] == 'Vegetable':
    df.loc[index, 'Datapoint'] = random.choice(vegetable)

for index, row in df.iterrows():
  if row['Subcategory'] == 'Sweets':
    df.loc[index, 'Datapoint'] = random.choice(sweets)

# %%
df.head()
# Out:
#     Category Subcategory       Datapoint Zero  One  Two Three Four Five
# 0       Both       Dairy            Milk  NaN  NaN  NaN   NaN  NaN  NaN
# 1  Unhealthy        Fats       Olive Oil  NaN  NaN  NaN   NaN  NaN  NaN
# 2  Unhealthy        Fats  Grape Seed Oil  NaN  NaN  NaN   NaN  NaN  NaN
# 3  Unhealthy        Fats     Avacado Oil  NaN  NaN  NaN   NaN  NaN  NaN
# 4    Healthy       Grain           Wheat  NaN  NaN  NaN   NaN  NaN  NaN

# %%
df.shape
# Out:
# (500, 9)

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %%
df.shape
# Out:
# (42, 9)

# %%
df.head()
# Out:
#     Category Subcategory       Datapoint Zero  One  Two Three Four Five
# 0       Both       Dairy            Milk  NaN  NaN  NaN   NaN  NaN  NaN
# 1  Unhealthy        Fats       Olive Oil  NaN  NaN  NaN   NaN  NaN  NaN
# 2  Unhealthy        Fats  Grape Seed Oil  NaN  NaN  NaN   NaN  NaN  NaN
# 3  Unhealthy        Fats     Avacado Oil  NaN  NaN  NaN   NaN  NaN  NaN
# 4    Healthy       Grain           Wheat  NaN  NaN  NaN   NaN  NaN  NaN

# %%
def fill_row(row):
    # Generate random integers for each cell such that the sum equals 500
    random_integers = np.random.randint(0, 500, size=6)
    total = random_integers.sum()

    # Scale the random integers to ensure they sum to 500
    if total != 0:
        random_integers = (random_integers / total) * 500

    # Cast the random integers to integers and fill the cells
    row[['Zero', 'One', 'Two', 'Three', 'Four', 'Five']] = random_integers.astype(int)
    return row

# Apply the modified fill_row function to each row in the DataFrame
df = df.apply(fill_row, axis=1)

# %%
df
# Out:
#      Category Subcategory       Datapoint  Zero  One  Two  Three  Four  Five
# 0        Both       Dairy            Milk    93   82    2     27   136   157
# 1   Unhealthy        Fats       Olive Oil   113   72  107     31    80    95
# 2   Unhealthy        Fats  Grape Seed Oil    99  106   68     46    56   123
# 3   Unhealthy        Fats     Avacado Oil   117   41    6    133    80   120
# 4     Healthy       Grain           Wheat    99   91   73     46    96    92
# 5        Both        Meat            Pork   154  102   14    146    24    56
# 6     Healthy   Vegetable         Spinach   174   84   77      7     8   148
# 7   Unhealthy        Fats          Butter    52  107  199     49     4    86
# 8        Both       Dairy          Cheese   111   77  155     20    21   113
# 9     Healthy       Fruit          Banana    81  164   50    133    32    37
# 10       Both       Dairy          Yogurt     5   23  165    152   126    25
# 11    Healthy       Fruit          Orange   117   88   67     94    19   113
# 12  Unhealthy      Sweets            Cake    24  150   55    116    94    58
# 13    Healthy       Fruit            Pear   127    7   68    123    67   105
# 14    Healthy   Vegetable          Potato    99   21   84     65   109   118
# 15    Healthy       Fruit          Grapes   144   44  179     93     5    33
# 16    Healthy   Vegetable        Cucumber    55   75   21      7   109   230
# 17    Healthy       Fruit          Cherry    90   39  159    117    23    69
# 18    Healthy       Grain            Oats    93  140   17     78    61   108
# 19       Both        Meat            Beef    23   49  137    130    35   124
# 20    Healthy   Vegetable         Cabbage   114   44  114     75    75    76
# 21    Healthy   Vegetable        Broccoli    57  120   62    122   116    20
# 22  Unhealthy      Sweets         Pudding    56   12   53     20   171   185
# 23       Both        Meat         Chicken    49   87  158     79    46    79
# 24  Unhealthy      Sweets             Pie   108   80   65    154    38    52
# 25  Unhealthy      Sweets           Candy     5   68  122    128     8   166
# 26       Both       Dairy           Cream    60    8   58    122   120   129
# 27       Both        Meat            Lamb    39  100    7    118    56   176
# 28    Healthy       Fruit           Apple    86    3  103     53   125   127
# 29  Unhealthy      Sweets       Ice Cream    73   83  141    103    72    25
# 30    Healthy       Grain            Rice    47   91   73    104    92    89
# 31       Both        Meat          Turkey   106    9  180     14   112    76
# 32    Healthy   Vegetable            Corn    18  187   47    109    13   122
# 33    Healthy   Vegetable          Tomato    46   26   33    142   144   105
# 34       Both        Meat            Fish    94  101  184     50    65     2
# 35    Healthy   Vegetable           Onion    78  139   50     84    90    55
# 36    Healthy       Grain            Corn   131   65  132     62    89    18
# 37  Unhealthy      Sweets       Chocolate    59   97  109     25    63   144
# 38    Healthy       Grain             Rye    36  140   53     77    76   115
# 39    Healthy   Vegetable         Lettuce    63  140   15     33   182    64
# 40    Healthy   Vegetable         Carrots   113   37  115     99    71    62
# 41    Healthy       Grain          Barley    98  125  144     31    41    58

# %%
df.to_csv('data.csv', index=False)
